# %% [markdown]
# <a href="https://colab.research.google.com/github/SandraPinto/Data-606-Capstone/blob/main/Capstone_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/SandraPinto/Data-606-Capstone/main/PRC%20Data%20Breach%20Chronology%20-%201.13.20.csv'
df1 = pd.read_csv(url)
# Dataset is now stored in a Pandas Dataframe

# %%
df1
# Out:
#      Date Made Public  ... Unnamed: 15
# 0            3/3/2006  ...         NaN
# 1            1/4/2012  ...         NaN
# 2           2/18/2012  ...         NaN
# 3           2/22/2012  ...         NaN
# 4           3/12/2012  ...         NaN
# ...               ...  ...         ...
# 9010       11/20/2009  ...         NaN
# 9011       11/17/2009  ...         NaN
# 9012       10/30/2009  ...         NaN
# 9013       10/28/2009  ...         NaN
# 9014       10/21/2009  ...         NaN
#
# [9015 rows x 16 columns]

# %%
columns = ["Unnamed: 13", "Unnamed: 14", "Unnamed: 15"] #define the columns to be removed
df1_clean = df1.drop(columns, axis=1)

# %%
df1_clean
# Out:
#      Date Made Public  ...   Longitude
# 0            3/3/2006  ...  -74.405661
# 1            1/4/2012  ... -122.419416
# 2           2/18/2012  ... -117.157255
# 3           2/22/2012  ...  -97.743061
# 4           3/12/2012  ... -117.157255
# ...               ...  ...         ...
# 9010       11/20/2009  ...         NaN
# 9011       11/17/2009  ...         NaN
# 9012       10/30/2009  ...         NaN
# 9013       10/28/2009  ...         NaN
# 9014       10/21/2009  ...         NaN
#
# [9015 rows x 13 columns]

# %%
df1_clean.head()
# Out:
#   Date Made Public  ...   Longitude
# 0         3/3/2006  ...  -74.405661
# 1         1/4/2012  ... -122.419416
# 2        2/18/2012  ... -117.157255
# 3        2/22/2012  ...  -97.743061
# 4        3/12/2012  ... -117.157255
#
# [5 rows x 13 columns]

# %%
df1_clean.index
# Out:
# RangeIndex(start=0, stop=9015, step=1)

# %%
df1_clean.isnull().sum()
# Out:
# Date Made Public              0
# Company                       0
# City                       3325
# State                       579
# Type of breach               89
# Type of organization          0
# Total Records                 6
# Description of incident       3
# Information Source           53
# Source URL                 5408
# Year of Breach                0
# Latitude                   2474
# Longitude                  2474
# dtype: int64

# %%
gk = df1_clean.groupby('Type of breach')
gk.first()
# Out:
#                Date Made Public  ...   Longitude
# Type of breach                   ...
# CARD                 10/24/2012  ...  -74.005973
# DISC                  3/14/2012  ... -117.157255
# HACK                   3/3/2006  ...  -74.405661
# INSD                   4/3/2012  ...  -88.993687
# PHYS                  3/31/2012  ... -121.290780
# PORT                   1/4/2012  ... -122.419416
# STAT                  4/25/2012  ...  -96.698886
# UNKN                  3/31/2012  ... -122.419416
#
# [8 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

plt = df1_clean.value_counts('Type of breach').plot.pie()

plt

# %%
import matplotlib.pyplot as plt

plt = df1_clean.value_counts('Type of organization').plot.pie()

plt

# %%
gkk = df1_clean.groupby(['Type of breach', 'Type of organization'])
  
# Print the first value in each group
gkk.first()
# Out:
#                                     Date Made Public  ...   Longitude
# Type of breach Type of organization                   ...
# CARD           BSF                        12/13/2012  ... -121.773297
#                BSO                          7/2/2013  ...  -93.265011
#                BSR                        10/24/2012  ...  -74.005973
#                EDU                          7/3/2012  ... -122.652500
#                MED                        11/30/2012  ...  -77.306373
# DISC           BSF                         3/14/2012  ... -117.157255
#                BSO                         3/31/2012  ... -121.494400
#                BSR                          1/4/2013  ...  -87.871474
#                EDU                        12/18/2012  ... -117.752305
#                GOV                         11/1/2012  ... -121.326319
#                MED                         3/19/2012  ... -122.271114
#                NGO                         10/5/2016  ... -122.275340
# ...
